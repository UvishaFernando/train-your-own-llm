# %%
with open("../output/combined_text.txt", "r", encoding="utf-8") as f:
    text_sequence = f.read()

len(text_sequence)
# Out:
# 9459

# %%
import sys
sys.path.append('..')

# %%
from minbpe import BasicTokenizer

tokenizer = BasicTokenizer()
tokenizer.train(text_sequence, vocab_size=1024)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from minbpe import BasicTokenizer
#       3 tokenizer = BasicTokenizer()
#       4 tokenizer.train(text_sequence, vocab_size=1024)
#
# File ~\Desktop\train-your-own-llm\notebooks\..\minbpe\__init__.py:1
# ----> 1 from .basic import BasicTokenizer
#
# File ~\Desktop\train-your-own-llm\notebooks\..\minbpe\basic.py:13
#       1 """
#       2 Minimal (byte-level) Byte Pair Encoding tokenizer.
#       3
#    (...)      9 - Does not handle any special tokens.
#      10 """
#      12 from tqdm import tqdm
# ---> 13 from .base import Tokenizer, get_stats, merge
#      16 class BasicTokenizer(Tokenizer):
#      18     def __init__(self):
#
# ModuleNotFoundError: No module named 'minbpe.base'
